# %% [markdown]
# <a href="https://colab.research.google.com/github/fierrofloresambarh-prog/diagrama-de-flujo-tienda-en-linea/blob/main/DF_tienda_en_linea.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
compra=float(input("ingresa el total de compra"))

if compra > 800:
  print("el envio es gratis")
  print("su total es:", compra)
else:
  costototal=compra + 150
  print("su total es:", costototal)
# Out:
# ingresa el total de compra1000
# el envio es gratis
# su total es: 1000.0

# %%
compra=float(input("ingresa el total de la compra"))

if compra > 800:
  print("el envio es gratis")
  print("su total es:", compra)
else:
  costototal=compra + 150
  print("su total es:", costototal)
# Out:
# ingresa el total de la compra200
# su total es: 350.0

# %% [markdown]
# ![texto del vínculo](https://raw.githubusercontent.com/fierrofloresambarh-prog/diagrama-de-flujo-tienda-en-linea/refs/heads/main/diagrama%20tienda%20en%20linea.png)
